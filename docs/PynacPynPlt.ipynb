# %% [markdown]
# # Pynac/Pynplt demo
# One of the most basic ways of working with Dynac is to feed the executable an input file, and then to use ``plotit`` to look at the output plots.  Here we show how this simple workflow can be performed in Pynac.  We create an empty working directory, copy the relevant files into it, and then move into that directory to work.
#
# First we import some stuff we need.

# %%
from Pynac.Core import Pynac
from Pynac.Plotting import PynPlt
from bokeh.io import output_notebook
import os
import shutil
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d9464b37-b92d-4c1e-9f29-bdc72b56b4fa">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Create and populate the working directory
# In our case, the relevant files are in the ``../tests`` directory, and so we copy them from there.

# %%
newDir = 'workingDir'
if os.path.isdir(newDir):
    shutil.rmtree(newDir)
os.mkdir(newDir)
filelist = [
    'ESS_with_SC_ana.in',
    'Spoke_F2F_field.txt',
    'MBL_F2F_field.txt',
    'HBL_F2F_field.txt',
    'ESS_RFQ_out_70mA.dst',
]
for f in filelist:
    shutil.copyfile('../tests/' + f, newDir + '/' + f)
os.chdir(newDir)

# %% [markdown]
# ## Run Pynac
# Create a Pynac object from the Dynac input file, and then run it.

# %%
pynacObject = Pynac('ESS_with_SC_ana.in')
pynacObject.run()

# %% [markdown]
# ## Plotting
# Create a plotting object.  This will pick up the plotting data that Pynac creates, and slice'n'dice it in preparation for plotting.  Then call the ``plotit()`` method.

# %%
plottingObject = PynPlt()
plottingObject.plotit()

os.chdir('..')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="100ee423-0af6-40a6-ba84-d0e56ac09425"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
